# %% [markdown]
# <a href="https://colab.research.google.com/github/SoheliPaul/Machine-Learning/blob/main/NLPlab2_561_Soheli.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  *text = "Soheli, a vibrant and determined individual, embraces life with a zest for adventure! 🌟 Born on 25/07/2001, she defies expectations and embodies the spirit of resilience. 🎉 A self-proclaimed explorer, she doesn't let obstacles hinder her path, turning challenges into opportunities. 💪 Don't underestimate her, for she is a force to be reckoned with! 🚀 Oh, did I mention her email is sohelipaul25@gmail.com? Feel free to drop her a message for a chat about life's wonders. If you want to catch up, how about meeting on the 10/02/2022 or the 05/09/2023, or 15/10/2022 ? 🗓️ And if you're feeling really adventurous, give her a call at 7001539043 or try reaching her on 9876543210 or maybe 91234567822, an invalid number she mistakenly shared once! 📞 #SoheliAdventures #BornToExplore #GirlPower #DontHoldBack"*

# %% [markdown]
# **Count the number of unique tokens in the text.**

# %%
text = "Soheli, a vibrant and determined individual, embraces life with a zest for adventure! 🌟 Born on 25/07/2001, she defies expectations and embodies the spirit of resilience. 🎉 A self-proclaimed explorer, she doesn't let obstacles hinder her path, turning challenges into opportunities. 💪 Don't underestimate her, for she is a force to be reckoned with! 🚀 Oh, did I mention her email is sohelipaul25@gmail.com? Feel free to drop her a message for a chat about life's wonders. If you want to catch up, how about meeting on the 10/02/2022 or the 05/09/2023, or 15/10/2022 ? 🗓️ And if you're feeling really adventurous, give her a call at 7001539043 or try reaching her on 9876543210 or maybe 91234567822, an invalid number she mistakenly shared once! 📞 #SoheliAdventures #BornToExplore #GirlPower #DontHoldBack"
# Tokenization
tokens = text.split()
unique_tokens = set(tokens)

# Counting unique tokens
num_unique_tokens = len(unique_tokens)
print(f"Number of unique tokens: {num_unique_tokens}")
# Out:
# Number of unique tokens: 102

# %% [markdown]
# **Count the number of punctuation characters and remove punctuations.**

# %%
import string

# Counting punctuation characters
num_punctuations = sum(1 for char in text if char in string.punctuation)
print(f"Number of punctuation characters: {num_punctuations}")

# Removing punctuations
text_without_punctuations = text.translate(str.maketrans('', '', string.punctuation))
print(f"Text without punctuations:\n{text_without_punctuations}")
# Out:
# Number of punctuation characters: 38
# Text without punctuations:
# Soheli a vibrant and determined individual embraces life with a zest for adventure 🌟 Born on 25072001 she defies expectations and embodies the spirit of resilience 🎉 A selfproclaimed explorer she doesnt let obstacles hinder her path turning challenges into opportunities 💪 Dont underestimate her for she is a force to be reckoned with 🚀 Oh did I mention her email is sohelipaul25gmailcom Feel free to drop her a message for a chat about lifes wonders If you want to catch up how about meeting on the 10022022 or the 05092023 or 15102022  🗓️ And if youre feeling really adventurous give her a call at 7001539043 or try reaching her on 9876543210 or maybe 91234567822 an invalid number she mistakenly shared once 📞 SoheliAdventures BornToExplore GirlPower DontHoldBack

# %% [markdown]
# **Plot the distribution of stopwords used in the text using barplot.**

# %%
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS
from collections import Counter

# Extracting stopwords from the text
stopwords_used = [word.lower() for word in tokens if word.lower() in STOPWORDS]

# Plotting the distribution of stopwords with increased figure size
plt.figure(figsize=(15, 6))  # Adjust the size as needed
stopwords_counter = Counter(stopwords_used)
stopwords_labels, stopwords_counts = zip(*stopwords_counter.items())

plt.bar(stopwords_labels, stopwords_counts)
plt.xlabel('Stopwords')
plt.ylabel('Frequency')
plt.title('Distribution of Stopwords in the Text')
plt.show()

# %% [markdown]
# **Remove the stopwords from the text.**

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

# Download stopwords from NLTK
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Remove stopwords
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(text)
filtered_tokens = [word for word in tokens if word.lower() not in stop_words and word.isalnum()]

# Reconstruct the text without stopwords
text_without_stopwords = ' '.join(filtered_tokens)
print(f"Text without stopwords:\n{text_without_stopwords}")
# Out:
# Text without stopwords:
# Soheli vibrant determined individual embraces life zest adventure Born defies expectations embodies spirit resilience explorer let obstacles hinder path turning challenges opportunities underestimate force reckoned Oh mention email sohelipaul25 Feel free drop message chat life wonders want catch meeting feeling really adventurous give call 7001539043 try reaching 9876543210 maybe 91234567822 invalid number mistakenly shared SoheliAdventures BornToExplore GirlPower DontHoldBack

# %% [markdown]
# **Plot the distribution of each POS Tag using a barplot.**

# %%
import nltk
from nltk import pos_tag
from collections import Counter

# Download POS tagger from NLTK
nltk.download('averaged_perceptron_tagger')

# POS tagging
pos_tags = pos_tag(filtered_tokens)

# Plotting the distribution of POS tags
pos_tags_counter = Counter(tag for word, tag in pos_tags)
pos_tags_labels, pos_tags_counts = zip(*pos_tags_counter.items())

plt.figure(figsize=(12, 6))
plt.bar(pos_tags_labels, pos_tags_counts)
plt.xlabel('POS Tags')
plt.ylabel('Frequency')
plt.title('Distribution of POS Tags in the Text')
plt.show()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %% [markdown]
# **Determine the number of unique lemma available in the text.**

# %%
from nltk.stem import WordNetLemmatizer

# Download WordNetLemmatizer from NLTK
nltk.download('wordnet')

# Lemmatization
lemmatizer = WordNetLemmatizer()
lemmas = [lemmatizer.lemmatize(word) for word in filtered_tokens]

# Counting unique lemmas
num_unique_lemmas = len(set(lemmas))
print(f"Number of unique lemmas: {num_unique_lemmas}")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Number of unique lemmas: 57

# %% [markdown]
# **Plot the frequency distribution of words in the text. Display only the top 10(most occurring) tokens in the chart.**

# %%
from nltk import FreqDist

# Frequency distribution of words
fdist = FreqDist(filtered_tokens)

# Plotting the top 10 most occurring tokens
plt.figure(figsize=(12, 6))
fdist.plot(10, title='Top 10 Most Occurring Tokens', cumulative=False)
plt.show()

# %% [markdown]
# **Find the number of unique bigrams, trigrams and quadgrams in the corpus**

# %%
from nltk import ngrams

# Function to get n-grams
def extract_ngrams(tokens, n):
    return list(ngrams(tokens, n))

# Extracting bigrams, trigrams, and quadgrams
bigrams = extract_ngrams(filtered_tokens, 2)
trigrams = extract_ngrams(filtered_tokens, 3)
quadgrams = extract_ngrams(filtered_tokens, 4)

# Counting unique bigrams, trigrams, and quadgrams
num_unique_bigrams = len(set(bigrams))
num_unique_trigrams = len(set(trigrams))
num_unique_quadgrams = len(set(quadgrams))

print(f"Number of unique bigrams: {num_unique_bigrams}")
print(f"Number of unique trigrams: {num_unique_trigrams}")
print(f"Number of unique quadgrams: {num_unique_quadgrams}")
# Out:
# Number of unique bigrams: 57
# Number of unique trigrams: 56
# Number of unique quadgrams: 55

# %% [markdown]
# **Find all dates and convert them to the DD-MM-YYYY format.**

# %%
from dateutil import parser
import re
# Function to convert dates to DD-MM-YYYY format
def convert_to_dd_mm_yyyy(date_str):
    try:
        date_obj = parser.parse(date_str)
        return date_obj.strftime('%d-%m-%Y')
    except ValueError:
        return None

# Extracting and converting dates
all_dates = re.findall(r'\b\d{1,2}[-/]\d{1,2}[-/]\d{4}\b|\b\d{4}[-/]\d{1,2}[-/]\d{1,2}\b', text)
converted_dates = [convert_to_dd_mm_yyyy(date) for date in all_dates]

# Filtering out None values (invalid dates)
valid_dates = [date for date in converted_dates if date is not None]

print(f"Original dates: {all_dates}")
print(f"Converted dates: {valid_dates}")
# Out:
# Original dates: ['25/07/2001', '10/02/2022', '05/09/2023', '15/10/2022']
# Converted dates: ['25-07-2001', '02-10-2022', '09-05-2023', '15-10-2022']

# %% [markdown]
# **Plot a distribution of the different values of year occurring in the text.**

# %%
# Extracting years using regex
year_pattern = re.compile(r'\b\d{4}\b')
years = re.findall(year_pattern, text)

# Plotting the distribution of years
year_counts = Counter(years)
year_labels, year_values = zip(*year_counts.items())

plt.figure(figsize=(12, 6))
plt.bar(year_labels, year_values)
plt.xlabel('Years')
plt.ylabel('Frequency')
plt.title('Distribution of Years in the Text')
plt.show()

# %% [markdown]
# **Determine whether the text contains any phone numbers in it. Ensure the phone numbers are valid if any. If an invalid phone number is found, remove it from the text.**

# %%
# Function to validate phone numbers
def is_valid_phone_number(phone_number):
    phone_number_pattern = re.compile(r'^\d{10}$')
    return bool(re.match(phone_number_pattern, phone_number))

# Extracting phone numbers using regex
phone_number_pattern = re.compile(r'\b\d{10}\b')
phone_numbers = re.findall(phone_number_pattern, text)

# Validating and removing invalid phone numbers
valid_phone_numbers = [number for number in phone_numbers if is_valid_phone_number(number)]
text_without_invalid_phone_numbers = re.sub(r'\b\d{11,}\b', '', text)

print(f"Original phone numbers: {phone_numbers}")
print(f"Valid phone numbers: {valid_phone_numbers}")
print(f"Text without invalid phone numbers:\n{text_without_invalid_phone_numbers}")
# Out:
# Original phone numbers: ['7001539043', '9876543210']
# Valid phone numbers: ['7001539043', '9876543210']
# Text without invalid phone numbers:
# Soheli, a vibrant and determined individual, embraces life with a zest for adventure! 🌟 Born on 25/07/2001, she defies expectations and embodies the spirit of resilience. 🎉 A self-proclaimed explorer, she doesn't let obstacles hinder her path, turning challenges into opportunities. 💪 Don't underestimate her, for she is a force to be reckoned with! 🚀 Oh, did I mention her email is sohelipaul25@gmail.com? Feel free to drop her a message for a chat about life's wonders. If you want to catch up, how about meeting on the 10/02/2022 or the 05/09/2023, or 15/10/2022 ? 🗓️ And if you're feeling really adventurous, give her a call at 7001539043 or try reaching her on 9876543210 or maybe , an invalid number she mistakenly shared once! 📞 #SoheliAdventures #BornToExplore #GirlPower #DontHoldBack

# %% [markdown]
# **Tokenization and Unique Tokens:**
#
# Insights: Tokenization breaks down text into individual units, providing a foundation for further analysis.
#
# Applications: Useful in natural language processing (NLP), sentiment analysis, and building word clouds.
#
# **Punctuation and Stopwords Removal:**
#
# Insights: Removing punctuation and stopwords enhances the focus on meaningful content in text.
#
# Applications: Improves the accuracy of text analysis tasks like sentiment analysis, topic modeling, and keyword extraction.
#
# **POS Tagging and Lemmatization:**
#
# Insights: POS tagging assigns grammatical information to words, and lemmatization reduces words to their base form.
#
# Applications: Valuable for information extraction, language understanding, and improving search relevance.
#
# **Frequency Distribution and Top Tokens:**
#
# Insights: Reveals the most frequent words in a text, highlighting key themes.
#
# Applications: Useful for identifying important terms in content, improving search engine optimization, and content summarization.
#
# **N-grams (Bigrams, Trigrams, Quadgrams):**
#
# Insights: Captures patterns of adjacent words, providing context to language.
#
# Applications: Enhances language modeling, predictive text input, and information retrieval systems.
#
# **Date Extraction and Conversion:**
#
# Insights: Identifies date information in various formats for standardization.
#
# Applications: Important for chronological analysis, event tracking, and organizing time-sensitive information.
#
# **Phone Number Validation and Removal:**
#
# Insights: Ensures the accuracy of phone number data by validating against a defined format.
#
# Applications: Useful in data cleaning, customer relationship management, and preventing errors in communication systems.
#
# **Insights from Invalid Phone Numbers:**
#
# Insights: Detects and handles errors in phone number data, ensuring data quality.
#
# Applications: Improves reliability in applications relying on phone numbers, such as contact databases and communication systems.
#
# **Date Format Standardization:**
#
# Insights: Converts dates to a consistent format for uniformity in analysis.
#
# Applications: Facilitates chronological sorting, accurate timeline visualization, and improves date-based querying in databases.
#
# **Year Distribution Analysis:**
#
# Insights: Examines the frequency of different years in the text.
#
# Applications: Useful for trend analysis, historical content exploration, and identifying significant periods.
